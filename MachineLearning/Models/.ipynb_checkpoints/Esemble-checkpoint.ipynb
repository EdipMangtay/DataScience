# %%
#Birden fazla modeli bir araya getirmek anlamındadır

# %%
#Bagging bir çok model hesaplamarı gelir ve bir oylama yapılır oylama sonrasında en iyi model seçilir

# %% [markdown]
# #Eğer çözüme ulaşmak istediğimiz problem regresyhon problemi ise burada bir ortalama alma yapılır

# %%
#Random forest bagging için en önemli modellerden biridir ve paralel eğitim yapılmaktadır

# %%
#Boostingte modellere tek tek gider örnek olarak bir tane modele gittti o modelin yanlış yaptığı tahminleri başka modele yollarız 
# diğer modelin çözemsini bekleriz taki en iyisi olana kadar

# %%
#En önemli farkları ardışık ve paralel çalışır baggin variance azalatmaya çalışırken boosting bias i azaltır

# %%
#Bagginte overfitting azaltmaya çalışır b urada variance azlatmaya çalışılır

# %%
#Random forest bir baggingtir tüm modeller ağaçtır  DT1,DT2,DT3.. gibi  farklı örneklemler verilir 
#Farklı stun ve kolonlar verilmesi gerekmektedir çakışma olmamalıdır farklı farklı özellikler verilir

# %%
#Sonuc = Mode(y1,y2,y3) Sınıflandırma için
#Regresyon sorunlarında: 1/n E i -> n yi ortalama alınır yani

# %%
#Neden random forest kullanılır, karar ağaçları default olarak kullanılırsa overfitting riski taşımaktadır fakat random forest içerisinde
# Variance düşürülür ve faha genelleşebilir sonuçlar gelebilir

# %%
# sıkıntııs : anlaşılması zor olabilir çok fazla ağaç var eğitim süresi biraz uzun olabilir ama boostinge göre daha hızlıdır çünkü parelel çalışmaktadır
