# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data  = np.linspace(0,10,20)

# %%
data1 = data*22

# %%
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
my_fig,my_axes = plt.subplots()

# %%
type(my_fig)
# Out:
# matplotlib.figure.Figure

# %%
my_fig,my_axes = plt.subplots()
my_axes.plot(data,data1, color = "#1E0703",alpha = 0.2)
my_axes.plot(data1,data)
plt.show()

# %%
(new_fig,new_axes)  = plt.subplots()
new_axes.plot(data1,data1 + 2, color = "blue",linewidth = 0.4)
new_axes.plot(data1,data1 + 10, color = "red",linewidth = 0.5)
new_axes.plot(data1,data1 + 20, color = "red",linestyle = "-.")

new_axes.plot(data1,data1 + 30, color = "#000000",linewidth = 0.5,marker = "o",markersize = 8, markerfacecolor = "red")


plt.show()

# %%
plt.scatter(data,data1, color="black")
plt.show()

# %%
#Histogram

# %%
new_arr = np.random.randint(0,100,50)

# %%
plt.hist(new_arr)
plt.show()

# %%
plt.boxplot(new_arr)
plt.show()

# %%
import seaborn as sns
sns.set_style("whitegrid")
sns.scatterplot(x="Height", y="Weight", data = data)
plt.xlabel("Height of Athlete")
plt.ylabel("Weight of Athlete")
plt.title("W vs H")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 import seaborn as sns
#       2 sns.set_style("whitegrid")
# ----> 3 sns.scatterplot(x="Height", y="Weight", data = data)
#       4 plt.xlabel("Height of Athlete")
#       5 plt.ylabel("Weight of Athlete")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
# ...
